# %%
import cv2
import numpy as np
import tensorflow as tf
import os 
import glob
import h5py
import time
import pprint
import random
import math
random.seed(83)
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def load_data1(is_train):
    if is_train:
        data_dir1 = os.path.join(os.getcwd(), 'train_set', "LR") # Join the Train dir to current directory
        data1 = glob.glob(os.path.join(data_dir1, "*.jpg"))[:200] + glob.glob(os.path.join(data_dir1, "*.jpg"))[500:700] + glob.glob(os.path.join(data_dir1, "*.jpg"))[1000:1200]# make set of all dataset file path
        
        data_dir2 = os.path.join(os.getcwd(), 'train_set', "HR") # Join the Train dir to current directory
        data2 = glob.glob(os.path.join(data_dir2, "*.jpg"))[:200] + glob.glob(os.path.join(data_dir2, "*.jpg"))[500:700] + glob.glob(os.path.join(data_dir2, "*.jpg"))[1000:1200] # make set of all dataset file path
    return data1, data2
# def load_data1(is_train):
#     if is_train:
#         data_dir1 = os.path.join(os.getcwd(), 'train_set', "LR") # Join the Train dir to current directory
#         data1 = glob.glob(os.path.join(data_dir1, "*.jpg")) # make set of all dataset file path
#         test1 = random.sample(data1, len(data1)//5) # make set of all test file path (identical to that in main)
#         train1 = [_ for _ in data1 if _ not in test1] # the complimentery set
#         train1 = random.sample(train1, len(train1)//2) # make set of all train file path
        
#         data_dir2 = os.path.join(os.getcwd(), 'train_set', "HR") # Join the Train dir to current directory
#         data2 = glob.glob(os.path.join(data_dir2, "*.jpg")) # make set of all dataset file path
#         test2 = random.sample(data2, len(data2)//5) # make set of all test file path (identical to that in main)
#         train2 = [_ for _ in data2 if _ not in test2] # the complimentery set
#         train2 = random.sample(train2, len(train2)//2) # make set of all train file path
#     return train1, train2

def make_sub_data1(data1,data2, padding, config):
    """
        Make the sub_data set
        Args:
            data : the set of all file path 
            padding : the image padding of input to label
            config : the all flags
    """
    sub_input_sequence = []
    sub_label_sequence = []
    for i in range(len(data1)):
        if config.is_train:
            input_=data1[i]
            label_=data2[i]
            
            
            input_=cv2.imread(input_)
            input_=cv2.resize(input_,None,fx = 2 ,fy = 2, interpolation = cv2.INTER_CUBIC)
            label_=cv2.imread(label_)
            
        if len(input_.shape) == 3: # is color
            h, w, c = input_.shape
        else:
            h, w = input_.shape # is grayscale
 
        nx, ny = 0, 0
        for x in range(0, h - config.image_size + 1, config.stride):
            nx += 1; ny = 0
            for y in range(0, w - config.image_size + 1, config.stride):
                ny += 1

                sub_input = input_[x: x + config.image_size, y: y + config.image_size] # 33 * 33
                sub_label = label_[x + padding: x + padding + config.label_size, y + padding: y + padding + config.label_size] # 21 * 21


                # Reshape the subinput and sublabel
                sub_input = sub_input.reshape([config.image_size, config.image_size, config.c_dim])
                sub_label = sub_label.reshape([config.label_size, config.label_size, config.c_dim])
                # Normialize
                sub_input =  sub_input / 255.0
                sub_label =  sub_label / 255.0
                
                #cv2.imshow("im1",sub_input)
                #cv2.imshow("im2",sub_label)
                #cv2.waitKey(0)

                # Add to sequence
                sub_input_sequence.append(sub_input)
                sub_label_sequence.append(sub_label)

        
    # NOTE: The nx, ny can be ignore in train
    return sub_input_sequence, sub_label_sequence, nx, ny

def make_data_hf1(input_, label_, config):
    """
        Make input data as h5 file format
        Depending on "is_train" (flag value), savepath would be change.
    """
    # Check the check dir, if not, create one
    if not os.path.isdir(os.path.join(os.getcwd(),config.checkpoint_dir)):
        os.makedirs(os.path.join(os.getcwd(),config.checkpoint_dir))

    if config.is_train:
        savepath = os.path.join(os.getcwd(), config.checkpoint_dir + '/train.h5')

    with h5py.File(savepath, 'w') as hf:
        hf.create_dataset('input', data=input_)
        hf.create_dataset('label', data=label_)

def input_setup1(config):
    """
        Read image files and make their sub-images and saved them as a h5 file format
    """

    # Load data path, if is_train False, get test data
    data1,data2 = load_data1(config.is_train)

    padding = abs(config.image_size - config.label_size) // 2

    # Make sub_input and sub_label, if is_train false more return nx, ny
    sub_input_sequence, sub_label_sequence, nx, ny = make_sub_data1(data1,data2, padding, config)


    # Make list to numpy array. With this transform
    arrinput = np.asarray(sub_input_sequence) # [?, 33, 33, 3]
    arrlabel = np.asarray(sub_label_sequence) # [?, 21, 21, 3]

    make_data_hf1(arrinput, arrlabel, config)
    
    return nx, ny



##############################################################################



def checkpoint_dir1(config):
    if config.is_train:
        return os.path.join('./{}'.format(config.checkpoint_dir), "train.h5")
    #else:
        #return os.path.join('./{}'.format(config.checkpoint_dir), "test.h5")
    
    



#########################################################################################

def read_data1(path):
    """
        Read h5 format data file

        Args:
            path: file path of desired file
            data: '.h5' file format that contains  input values
            label: '.h5' file format that contains label values 
    """
    with h5py.File(path, 'r') as hf:
        input_ = np.array(hf.get('input'))
        label_ = np.array(hf.get('label'))
        return input_, label_

    
    
######################################
#                                    #
#          FOR TESTING ONLY          #
#                                    #
######################################    
    
    

# Get the Image
def imread(path):
    img = cv2.imread(path)
    return img

def imsave(image, path, config):
    #checkimage(image)
    # Check the check dir, if not, create one
    if not os.path.isdir(os.path.join(os.getcwd(),config.result_dir)):
        os.makedirs(os.path.join(os.getcwd(),config.result_dir))

    # NOTE: because normial, we need mutlify 255 back    
    cv2.imwrite(os.path.join(os.getcwd(),path),image * 255.)

def checkimage(image):
    cv2.imshow('test', image)
    cv2.waitKey(0)

def modcrop(img, scale = 3):
    """
        To scale down and up the original image, first thing to do is to have no remainder while scaling operation.
    """
    # Check the image is grayscale
    if len(img.shape) ==3:
        h, w, _ = img.shape
        h = (h // scale) * scale
        w = (w // scale) * scale
        img = img[0:h, 0:w, :]
    else:
        h, w = img.shape
        h = (h // scale) * scale
        w = (w // scale) * scale
        img = img[0:h, 0:w]
    return img

def checkpoint_dir(config):
    if config.is_train:
        return os.path.join('./{}'.format(config.checkpoint_dir), 'train.h5')
    else:
        return os.path.join('./{}'.format(config.checkpoint_dir), 'test.h5')

# def preprocess(path, scale = 3):
#     img = imread(path)
#     #img=cv2.resize(img,None,fx = 2 ,fy = 2, interpolation = cv2.INTER_CUBIC)

#     label_ = modcrop(img, scale)

#     bicbuic_img = cv2.resize(label_, None, fx = 1.0/scale, fy = 1.0/scale, interpolation = cv2.INTER_CUBIC)# Resize by scaling factor
#     input_ = cv2.resize(bicbuic_img, None, fx = scale, fy = scale, interpolation = cv2.INTER_CUBIC)# Resize by scaling factor
#     return input_, label_
def prepare_data(dataset='Train',Input_img=''):
    """
        Args:
            dataset: choose train dataset or test dataset
            For train dataset, output data would be ['.../t1.bmp', '.../t2.bmp',..., 't99.bmp']
    """
    if dataset == 'Train':
        data_dir = os.path.join(os.getcwd(), dataset) # Join the Train dir to current directory
        data = glob.glob(os.path.join(data_dir, '*.*')) # make set of all dataset file path
    else:
        if Input_img !='':
            data = [os.path.join(os.getcwd(),Input_img)]
        else:
            data_dir = os.path.join(os.path.join(os.getcwd(), dataset), 'Set5')
            data = glob.glob(os.path.join(data_dir, '*.*')) # make set of all dataset file path
    print(data)
    return data

def load_data(is_train, test_img):
    """
        Args:
            is_train: decides if we choose train dataset or test dataset
            For train dataset, output data would be ['.../t1.bmp', '.../t2.bmp',..., 't99.bmp']
    """
    if is_train:
        data_dir = os.path.join(os.getcwd(), 'Train') # Join the Train dir to current directory
        data = glob.glob(os.path.join(data_dir, '*.*')) # make set of all dataset file path
    else:
        if test_img != '':
            return [os.path.join(os.getcwd(), test_img)]
        data_dir = os.path.join(os.path.join(os.getcwd(), 'Test'), 'Set5')
        data = glob.glob(os.path.join(data_dir, '*.*')) # make set of all dataset file path
    return data

def make_sub_data2(data, padding, config):
    """
        Make the sub_data set
        Args:
            data : the set of all file path 
            padding : the image padding of input to label
            config : the all flags
    """
    sub_input_sequence = []
#     sub_label_sequence = []
    for i in range(len(data)):
        input_ = cv2.imread(data[i])
        input_=cv2.resize(input_,None,fx = 2 ,fy = 2, interpolation = cv2.INTER_CUBIC)

        if len(input_.shape) == 3: # is color
            h, w, c = input_.shape
        else:
            h, w = input_.shape # is grayscale

        nx, ny = 0, 0
        for x in range(0, h - config.image_size + 1, config.stride):
            nx += 1; ny = 0
            for y in range(0, w - config.image_size + 1, config.stride):
                ny += 1

                sub_input = input_[x: x + config.image_size, y: y + config.image_size] # 33 * 33
#                 sub_label = label_[x + padding: x + padding + config.label_size, y + padding: y + padding + config.label_size] # 21 * 21

                # Reshape the subinput and sublabel
                sub_input = sub_input.reshape([config.image_size, config.image_size, config.c_dim])
#                 sub_label = sub_label.reshape([config.label_size, config.label_size, config.c_dim])
                # Normialize
                sub_input =  sub_input / 255.0
#                 sub_label =  sub_label / 255.0

                #cv2.imshow('im1',sub_input)
                #cv2.imshow('im2',sub_label)
                #cv2.waitKey(0)

                # Add to sequence
                sub_input_sequence.append(sub_input)
#                 sub_label_sequence.append(sub_label)

#     return sub_input_sequence, sub_label_sequence, nx, ny
    return sub_input_sequence, nx, ny

def read_data(path):
    """
        Read h5 format data file

        Args:
            path: file path of desired file
            data: '.h5' file format that contains  input values
            label: '.h5' file format that contains label values 
    """
    with h5py.File(path, 'r') as hf:
        input_ = np.array(hf.get('input'))
        label_ = np.array(hf.get('label'))
        return input_, label_

def make_data_hf2(input_, config):
    """
        Make input data as h5 file format
        Depending on 'is_train' (flag value), savepath would be change.
    """
    # Check the check dir, if not, create one
    if not os.path.isdir(os.path.join(os.getcwd(),config.checkpoint_dir)):
        os.makedirs(os.path.join(os.getcwd(),config.checkpoint_dir))

    if config.is_train:
        savepath = os.path.join(os.getcwd(), config.checkpoint_dir + '/train.h5')
    else:
        savepath = os.path.join(os.getcwd(), config.checkpoint_dir + '/test.h5')

    with h5py.File(savepath, 'w') as hf:
        hf.create_dataset('input', data=input_)

def merge(images, size, c_dim):
    """
        images is the sub image set, merge it
    """
    h, w = images.shape[1], images.shape[2]
    print(h, w)
    print(size[0], size[1])
    img = np.zeros((h*size[0], w*size[1], c_dim))
    for idx, image in enumerate(images):
        i = idx % size[1]
        j = idx // size[1]
        img[j * h : j * h + h, i * w : i * w + w, :] = image
        #cv2.imshow('srimg',img)
        #cv2.waitKey(0)

    return img

def input_setup2(config):
    """
        Read image files and make their sub-images and saved them as a h5 file format
    """

    # Load data path, if is_train False, get test data
    data = load_data(config.is_train, config.test_img)

    padding = abs(config.image_size - config.label_size) // 2

    # Make sub_input and sub_label, if is_train false more return nx, ny
#     sub_input_sequence, sub_label_sequence, nx, ny = make_sub_data2(data, padding, config)
    sub_input_sequence, nx, ny = make_sub_data2(data, padding, config)

    # Make list to numpy array. With this transform
    arrinput = np.asarray(sub_input_sequence) # [?, 33, 33, 3]
#     arrlabel = np.asarray(sub_label_sequence) # [?, 21, 21, 3]

    make_data_hf2(arrinput, config)

    return nx, ny

def psnr(img1, img2):
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %%
class SRCNN(object):

    def __init__(self,sess, image_size, label_size,c_dim):
        self.sess = sess
        self.image_size = image_size
        self.label_size = label_size
        self.c_dim = c_dim
        self.build_model()
        
    def train(self, config):
            # NOTE : if train, the nx, ny are ingnored
            nx, ny = input_setup1(config)
            print(0)
            data_dir = checkpoint_dir1(config)
            print(data_dir)
            
            input_, label_ = read_data1(data_dir)
            print('input_ =', input_[0:3])
            #print(input_)
            # Stochastic gradient descent with the standard backpropagation
            #self.train_op = tf.train.GradientDescentOptimizer(config.learning_rate).minimize(self.loss)
            self.train_op = tf.train.AdamOptimizer(learning_rate=config.learning_rate).minimize(self.loss)
            tf.global_variables_initializer().run()
            counter = 0
            time_ = time.time()
            print('time_: ', time_)
            # Train
            if config.is_train:
                print("Now Start Training...")
                for ep in range(config.epoch):
                    # Run by batch images
                    batch_idxs = len(input_) // config.batch_size
                    print('len(input_) =', batch_idxs)
                    for idx in range(0, batch_idxs):
                        batch_images = input_[idx * config.batch_size : (idx + 1) * config.batch_size]
                        batch_labels = label_[idx * config.batch_size : (idx + 1) * config.batch_size]
                        counter += 1
                        _, err = self.sess.run([self.train_op, self.loss], feed_dict={self.images: batch_images, self.labels: batch_labels})

                        if counter % 10 == 0:
                            print("Epoch: [%2d], step: [%2d], time: [%4.4f], loss: [%.8f]" % ((ep+1), counter, time.time()-time_, err))
                            #print(label_[1] - self.pred.eval({self.images: input_})[1],'loss:]',err)
                        if counter % 10 == 0:
                            self.save(config.checkpoint_dir, counter)

                            
    def build_model(self):
        self.images = tf.placeholder(tf.float32, [None, self.image_size, self.image_size, self.c_dim], name='images')
        self.labels = tf.placeholder(tf.float32, [None, self.label_size, self.label_size, self.c_dim], name='labels')
        
        self.weights = {
            'w1': tf.Variable(tf.random_normal([9, 9, self.c_dim, 128], stddev=1e-3), name='w1'),
            'w2': tf.Variable(tf.random_normal([1, 1, 128, 64], stddev=1e-3), name='w2'),
            'w3': tf.Variable(tf.random_normal([5, 5, 64, self.c_dim], stddev=1e-3), name='w3')
        }

        self.biases = {
            'b1': tf.Variable(tf.zeros([128], name='b1')),
            'b2': tf.Variable(tf.zeros([64], name='b2')),
            'b3': tf.Variable(tf.zeros([self.c_dim], name='b3'))
        }
        
        self.pred = self.model()
        
        self.loss = tf.reduce_mean(tf.square(self.labels - self.pred))

        self.saver = tf.train.Saver() # To save checkpoint

    def model(self):
        conv1 = tf.nn.relu(tf.nn.conv2d(self.images, self.weights['w1'], strides=[1,1,1,1], padding='VALID') + self.biases['b1'])
        conv2 = tf.nn.relu(tf.nn.conv2d(conv1, self.weights['w2'], strides=[1,1,1,1], padding='SAME') + self.biases['b2'])
        conv3 = tf.nn.conv2d(conv2, self.weights['w3'], strides=[1,1,1,1], padding='VALID') + self.biases['b3'] # This layer don't need ReLU
        return conv3

    
    
    def save(self, checkpoint_dir, step):
        """
            To save the checkpoint use to test or pretrain
        """
        model_name = "SRCNN.model"
        model_dir = "%s_%s" % ("srcnn", self.label_size)
        checkpoint_dir = os.path.join(checkpoint_dir, model_dir)

        if not os.path.exists(checkpoint_dir):
             os.makedirs(checkpoint_dir)

        self.saver.save(self.sess,os.path.join(checkpoint_dir, model_name),global_step=step)
        
        
        
      # YG  
#     def test(self, config):
#         print('Testing...')
#         nx, ny = input_setup2(config)
#         data_dir = checkpoint_dir(config)
#         input_, label_ = read_data(data_dir)
#         self.load(config.checkpoint_dir)
        
#         # Test
#         result = self.pred.eval({self.images: input_})
#         image = merge(result, [nx, ny], self.c_dim)
#         #image_LR = merge(input_, [nx, ny], self.c_dim)
#         #checkimage(image_LR)
#         # Saving Image
#         base, ext = os.path.basename(config.test_img).split('.')
#         imsave(image, os.path.join(config.result_dir, base + '.png'), config)
    
    # YM
    def test(self, config):
        print('Testing...')
        nx, ny = input_setup2(config)
        data_dir = checkpoint_dir(config)
        input_, label_ = read_data(data_dir)
        self.load(config.checkpoint_dir)
        # Test
        result = self.pred.eval({self.images: input_})
        image = merge(result, [nx, ny], self.c_dim)
     
        base, ext = os.path.basename(config.test_img).split('.')
        
        test_files =random.sample(files, len(files)//5) # a list of strings (the paths of each image)
        LR_image = imread(os.path.join(os.path.join(os.getcwd(),'train_set',"LR"), base + '.jpg'))
        LR_h = LR_image.shape[1]*2
        LR_w = LR_image.shape[0]*2  
        image = cv2.resize(image,(LR_h,LR_w))
        
        imsave(image, os.path.join(config.result_dir, base + '.png'), config)

    def load(self, checkpoint_dir):
        """
            To load the checkpoint use to test or pretrain
        """
        model_dir = '%s_%s' % ('srcnn', self.label_size)# give the model name by label_size
        checkpoint_dir = os.path.join(checkpoint_dir, model_dir)
        ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
        
        # Check the checkpoint is exist 
        if ckpt and ckpt.model_checkpoint_path:
            ckpt_path = str(ckpt.model_checkpoint_path) # convert the unicode to string
            self.saver.restore(self.sess, os.path.join(os.getcwd(), ckpt_path))
#             print('Success! %s'% ckpt_path)
        else:
            print('Loading failed.')
            
    def save(self, checkpoint_dir, step):
        """
            To save the checkpoint use to test or pretrain
        """
        model_name = 'SRCNN.model'
        model_dir = '%s_%s' % ('srcnn', self.label_size)
        checkpoint_dir = os.path.join(checkpoint_dir, model_dir)

        if not os.path.exists(checkpoint_dir):
             os.makedirs(checkpoint_dir)

        self.saver.save(self.sess,
                        os.path.join(checkpoint_dir, model_name),
                        global_step=step)

# %%
class this_config():
    def __init__(self, is_train=True):
        self.epoch = 1
        self.image_size = 33
        self.label_size = 21
        self.c_dim = 3
        self.is_train = is_train
        self.scale = 3
        self.stride = 21
        self.checkpoint_dir = "checkpoint1"
        self.learning_rate = 1e-4
        self.batch_size = 128
        self.result_dir = 'result'
        self.test_img = '' # Do not change this.
        
arg = this_config()
print("Hello TA! We are group 7. Thank you for your work for us. Hope you have a happy day!")

with tf.Session() as sess:
    FLAGS = arg
    srcnn = SRCNN(sess,
                  image_size = FLAGS.image_size,
                  label_size = FLAGS.label_size,
                  c_dim = FLAGS.c_dim)
    
    # Training
    srcnn.train(FLAGS)
    
    # Testing
    print(os.getcwd())
    files = glob.glob(os.path.join(os.getcwd(), 'train_set', 'LR', '*.jpg'))
    print(files[0:3])
    test_files = random.sample(files, len(files)//5) # a list of strings (the paths of each image)
    
    FLAGS.is_train = False
    count = 1
    for f in test_files:
        FLAGS.test_img = f
        print('Saving ', count, '/', len(test_files), ': ', FLAGS.test_img, '\n')
        count += 1
        srcnn.test(FLAGS)
        
    # PSNR
    #result_files = glob.glob(os.path.join(os.getcwd(), 'result', '*.png'))
    res_imgs = glob.glob(os.path.join(os.getcwd(), 'result', '*.png'))
    psnr_total = []
    print(test_files[0:3])
    print(res_imgs[0:3])
    for test_img, res_img in zip(test_files, res_imgs):   
        
        print(test_img)
        print(res_img)
        img1 = cv2.imread(test_img, cv2.IMREAD_COLOR)
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2YCrCb)[6: -6, 6: -6, 0] 
        img2 = cv2.imread(res_img, cv2.IMREAD_COLOR)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2YCrCb)[6: -6, 6: -6, 0] 
        img1 = cv2.resize(img1,(img2.shape[1],img2.shape[0]))
        psnr_total.append(psnr(img1,img2))
            
    print(np.mean(psnr_total))
# Out:
# Hello TA! We are group 7. Thank you for your work for us. Hope you have a happy day!
# 0
# ./checkpoint1/train.h5
# input_ = [[[[0.54509804 0.49411765 0.49411765]
#    [0.5254902  0.47843137 0.47843137]
#    [0.49411765 0.45490196 0.45490196]
#    ...
#    [0.24705882 0.2627451  0.28235294]
#    [0.27058824 0.27843137 0.29803922]
#    [0.32156863 0.32156863 0.34117647]]
#
#   [[0.54509804 0.49803922 0.49803922]
#    [0.52941176 0.48235294 0.48235294]
#    [0.50196078 0.4627451  0.4627451 ]
#    ...
#    [0.24705882 0.25882353 0.27843137]
#    [0.2627451  0.27058824 0.29019608]
#    [0.31764706 0.31764706 0.33333333]]
#
#   [[0.54509804 0.49803922 0.49803922]
#    [0.53333333 0.49019608 0.48627451]
#    [0.51372549 0.4745098  0.47058824]
#    ...
#    [0.24705882 0.25490196 0.2745098 ]
#    [0.25490196 0.2627451  0.27843137]
#    [0.30588235 0.30588235 0.32156863]]
#
#   ...
#
#   [[0.58039216 0.51764706 0.52156863]
#    [0.58431373 0.52156863 0.5254902 ]
#    [0.59215686 0.53333333 0.5372549 ]
#    ...
#    [0.61176471 0.58039216 0.56862745]
#    [0.61176471 0.58431373 0.56862745]
#    [0.61568627 0.58039216 0.56862745]]
#
#   [[0.56078431 0.49803922 0.50588235]
#    [0.56862745 0.50980392 0.51372549]
#    [0.58039216 0.52156863 0.5254902 ]
#    ...
#    [0.60784314 0.58431373 0.57254902]
#    [0.61176471 0.58431373 0.57254902]
#    [0.61176471 0.58039216 0.56862745]]
#
#   [[0.54901961 0.49411765 0.50196078]
#    [0.55686275 0.50196078 0.50980392]
#    [0.57254902 0.51764706 0.5254902 ]
#    ...
#    [0.60392157 0.58039216 0.56862745]
#    [0.61176471 0.58823529 0.57647059]
#    [0.61176471 0.58431373 0.57254902]]]
#
#
#  [[[0.35686275 0.34901961 0.37254902]
#    [0.35294118 0.34509804 0.36862745]
#    [0.35294118 0.34901961 0.37254902]
#    ...
#    [0.29803922 0.30588235 0.30980392]
#    [0.29019608 0.29803922 0.30196078]
#    [0.29019608 0.29803922 0.30196078]]
#
#   [[0.35686275 0.34901961 0.37254902]
#    [0.35686275 0.34509804 0.36862745]
#    [0.35294118 0.34901961 0.37254902]
#    ...
#    [0.30196078 0.30980392 0.31372549]
#    [0.29411765 0.30196078 0.30588235]
#    [0.29411765 0.30196078 0.30196078]]
#
#   [[0.36078431 0.34901961 0.37254902]
#    [0.36078431 0.34901961 0.37254902]
#    [0.35294118 0.34509804 0.37254902]
#    ...
#    [0.30980392 0.31764706 0.32156863]
#    [0.29803922 0.30588235 0.30980392]
#    [0.29411765 0.30196078 0.30588235]]
#
#   ...
#
#   [[0.57647059 0.54117647 0.54117647]
#    [0.58039216 0.54117647 0.54117647]
#    [0.58431373 0.54509804 0.54509804]
#    ...
#    [0.18823529 0.21568627 0.22745098]
#    [0.23137255 0.25882353 0.27058824]
#    [0.28235294 0.30980392 0.32156863]]
#
#   [[0.57647059 0.5372549  0.5372549 ]
#    [0.57647059 0.5372549  0.5372549 ]
#    [0.58039216 0.54117647 0.54117647]
#    ...
#    [0.16470588 0.19215686 0.20392157]
#    [0.21960784 0.24705882 0.25882353]
#    [0.2745098  0.30196078 0.31764706]]
#
#   [[0.57254902 0.52941176 0.52941176]
#    [0.56862745 0.52941176 0.52941176]
#    [0.57647059 0.5372549  0.53333333]
#    ...
#    [0.14901961 0.18039216 0.18431373]
#    [0.20784314 0.23529412 0.24313725]
#    [0.27058824 0.29803922 0.30980392]]]
#
#
#  [[[0.49411765 0.49019608 0.49803922]
#    [0.50588235 0.50196078 0.50980392]
#    [0.4745098  0.47058824 0.47843137]
#    ...
#    [0.4        0.40784314 0.42352941]
#    [0.39215686 0.40784314 0.42352941]
#    [0.38823529 0.40392157 0.41960784]]
#
#   [[0.47843137 0.4745098  0.48235294]
#    [0.49803922 0.49411765 0.50196078]
#    [0.47843137 0.4745098  0.48235294]
#    ...
#    [0.39607843 0.40784314 0.42352941]
#    [0.39215686 0.40392157 0.42352941]
#    [0.38823529 0.40392157 0.41960784]]
#
#   [[0.45098039 0.44705882 0.45490196]
#    [0.48627451 0.48235294 0.49019608]
#    [0.49019608 0.48627451 0.49411765]
#    ...
#    [0.39607843 0.40392157 0.42352941]
#    [0.39215686 0.40392157 0.41960784]
#    [0.38823529 0.4        0.41960784]]
#
#   ...
#
#   [[0.54901961 0.54117647 0.54117647]
#    [0.52941176 0.52156863 0.52156863]
#    [0.50980392 0.50196078 0.50980392]
#    ...
#    [0.30980392 0.30980392 0.32941176]
#    [0.22745098 0.22352941 0.23921569]
#    [0.18431373 0.18039216 0.19215686]]
#
#   [[0.55686275 0.54509804 0.54509804]
#    [0.53333333 0.5254902  0.52941176]
#    [0.51764706 0.50980392 0.51372549]
#    ...
#    [0.29019608 0.28627451 0.30196078]
#    [0.21960784 0.21176471 0.22352941]
#    [0.20392157 0.19607843 0.20392157]]
#
#   [[0.56078431 0.54901961 0.54509804]
#    [0.5372549  0.53333333 0.52941176]
#    [0.52156863 0.51764706 0.52156863]
#    ...
#    [0.28627451 0.27843137 0.29019608]
#    [0.24313725 0.23137255 0.23921569]
#    [0.25098039 0.24313725 0.24705882]]]]
# time_:  1541652287.056229
# Now Start Training...
# len(input_) = 2301
# Epoch: [ 1], step: [10], time: [9.3723], loss: [0.18091173]
# Epoch: [ 1], step: [20], time: [19.0771], loss: [0.12429326]
# Epoch: [ 1], step: [30], time: [28.2847], loss: [0.09637317]
# Epoch: [ 1], step: [40], time: [37.6854], loss: [0.01436936]
# Epoch: [ 1], step: [50], time: [45.9880], loss: [0.02892142]
# Epoch: [ 1], step: [60], time: [54.2040], loss: [0.00600983]
# Epoch: [ 1], step: [70], time: [62.7096], loss: [0.02192214]
# Epoch: [ 1], step: [80], time: [71.0620], loss: [0.02453710]
# Epoch: [ 1], step: [90], time: [80.0180], loss: [0.01234519]
# Epoch: [ 1], step: [100], time: [88.3904], loss: [0.01808306]
# Epoch: [ 1], step: [110], time: [97.4283], loss: [0.00464321]
# Epoch: [ 1], step: [120], time: [105.6405], loss: [0.00362975]
# Epoch: [ 1], step: [130], time: [113.9075], loss: [0.01567233]
# Epoch: [ 1], step: [140], time: [123.5957], loss: [0.04474495]
# Epoch: [ 1], step: [150], time: [133.2149], loss: [0.01632812]
# Epoch: [ 1], step: [160], time: [141.7950], loss: [0.07936982]
# Epoch: [ 1], step: [170], time: [152.0268], loss: [0.00667427]
# Epoch: [ 1], step: [180], time: [160.5056], loss: [0.02101433]
# Epoch: [ 1], step: [190], time: [169.9307], loss: [0.04107758]
# Epoch: [ 1], step: [200], time: [178.8151], loss: [0.06084263]
# Epoch: [ 1], step: [210], time: [187.1265], loss: [0.01699786]
# Epoch: [ 1], step: [220], time: [196.7767], loss: [0.02328769]
# Epoch: [ 1], step: [230], time: [204.9738], loss: [0.01510200]
# Epoch: [ 1], step: [240], time: [213.9965], loss: [0.03212759]
# Epoch: [ 1], step: [250], time: [222.1954], loss: [0.00417677]
# Epoch: [ 1], step: [260], time: [230.3396], loss: [0.00188055]
# Epoch: [ 1], step: [270], time: [238.5761], loss: [0.02276508]
# Epoch: [ 1], step: [280], time: [246.9048], loss: [0.01948323]
# Epoch: [ 1], step: [290], time: [255.1788], loss: [0.01426370]
# Epoch: [ 1], step: [300], time: [263.3857], loss: [0.03895424]
# Epoch: [ 1], step: [310], time: [271.6431], loss: [0.06905841]
# Epoch: [ 1], step: [320], time: [280.1360], loss: [0.02156563]
# Epoch: [ 1], step: [330], time: [288.7774], loss: [0.01213246]
# Epoch: [ 1], step: [340], time: [297.2445], loss: [0.05556470]
# Epoch: [ 1], step: [350], time: [305.5969], loss: [0.01224075]
# Epoch: [ 1], step: [360], time: [313.9360], loss: [0.02470072]
# Epoch: [ 1], step: [370], time: [322.2221], loss: [0.00829014]
# Epoch: [ 1], step: [380], time: [331.7219], loss: [0.01984000]
# Epoch: [ 1], step: [390], time: [340.0008], loss: [0.02547637]
# Epoch: [ 1], step: [400], time: [348.1813], loss: [0.02779587]
# Epoch: [ 1], step: [410], time: [356.4986], loss: [0.02051805]
# Epoch: [ 1], step: [420], time: [364.7448], loss: [0.01560803]
# Epoch: [ 1], step: [430], time: [372.9782], loss: [0.01630854]
# Epoch: [ 1], step: [440], time: [381.2211], loss: [0.02417676]
# Epoch: [ 1], step: [450], time: [389.3567], loss: [0.00210080]
# Epoch: [ 1], step: [460], time: [397.5638], loss: [0.01042636]
# Epoch: [ 1], step: [470], time: [405.7098], loss: [0.02649583]
# Epoch: [ 1], step: [480], time: [413.9309], loss: [0.01119677]
# Epoch: [ 1], step: [490], time: [422.1629], loss: [0.02865540]
# Epoch: [ 1], step: [500], time: [430.5292], loss: [0.02733617]
# Epoch: [ 1], step: [510], time: [438.6945], loss: [0.06098362]
# Epoch: [ 1], step: [520], time: [446.9584], loss: [0.03425485]
# Epoch: [ 1], step: [530], time: [455.1593], loss: [0.00470590]
# Epoch: [ 1], step: [540], time: [463.8621], loss: [0.03343401]
# Epoch: [ 1], step: [550], time: [472.3573], loss: [0.03709406]
# Epoch: [ 1], step: [560], time: [480.5404], loss: [0.00730817]
# Epoch: [ 1], step: [570], time: [488.7553], loss: [0.05900986]
# Epoch: [ 1], step: [580], time: [497.0457], loss: [0.02083984]
# Epoch: [ 1], step: [590], time: [506.0300], loss: [0.04312380]
# Epoch: [ 1], step: [600], time: [514.4756], loss: [0.01292443]
# Epoch: [ 1], step: [610], time: [522.9919], loss: [0.00953087]
# Epoch: [ 1], step: [620], time: [531.2483], loss: [0.01471760]
# Epoch: [ 1], step: [630], time: [539.8103], loss: [0.00448822]
# Epoch: [ 1], step: [640], time: [548.2640], loss: [0.01533950]
# Epoch: [ 1], step: [650], time: [556.7255], loss: [0.00311443]
# Epoch: [ 1], step: [660], time: [565.5005], loss: [0.00845759]
# Epoch: [ 1], step: [670], time: [573.9025], loss: [0.00360660]
# Epoch: [ 1], step: [680], time: [582.3064], loss: [0.01801575]
# Epoch: [ 1], step: [690], time: [591.0541], loss: [0.02351423]
# Epoch: [ 1], step: [700], time: [599.6112], loss: [0.01948216]
# Epoch: [ 1], step: [710], time: [607.9887], loss: [0.02569251]
# Epoch: [ 1], step: [720], time: [616.5139], loss: [0.04027178]
# Epoch: [ 1], step: [730], time: [624.6953], loss: [0.04296882]
# Epoch: [ 1], step: [740], time: [632.9229], loss: [0.01505661]
# Epoch: [ 1], step: [750], time: [641.1395], loss: [0.01290183]
# Epoch: [ 1], step: [760], time: [649.3883], loss: [0.02258490]
# Epoch: [ 1], step: [770], time: [657.9373], loss: [0.00995798]
# Epoch: [ 1], step: [780], time: [666.4032], loss: [0.00745806]
# Epoch: [ 1], step: [790], time: [674.8879], loss: [0.02355229]
# Epoch: [ 1], step: [800], time: [683.3039], loss: [0.00519794]
# Epoch: [ 1], step: [810], time: [691.6357], loss: [0.02160005]
# Epoch: [ 1], step: [820], time: [699.9880], loss: [0.01659285]
# Epoch: [ 1], step: [830], time: [708.7963], loss: [0.00912639]
# Epoch: [ 1], step: [840], time: [717.3162], loss: [0.04345183]
# Epoch: [ 1], step: [850], time: [725.5666], loss: [0.02177417]
# Epoch: [ 1], step: [860], time: [733.7265], loss: [0.04926902]
# Epoch: [ 1], step: [870], time: [741.9611], loss: [0.01616453]
# Epoch: [ 1], step: [880], time: [750.2480], loss: [0.00302250]
# Epoch: [ 1], step: [890], time: [758.3933], loss: [0.00557341]
# Epoch: [ 1], step: [900], time: [766.6156], loss: [0.01411387]
# Epoch: [ 1], step: [910], time: [774.7837], loss: [0.03871153]
# Epoch: [ 1], step: [920], time: [783.2028], loss: [0.02032204]
# Epoch: [ 1], step: [930], time: [792.9564], loss: [0.01384801]
# Epoch: [ 1], step: [940], time: [801.1267], loss: [0.02444248]
# Epoch: [ 1], step: [950], time: [809.2722], loss: [0.01956686]
# Epoch: [ 1], step: [960], time: [817.4873], loss: [0.03159335]
# Epoch: [ 1], step: [970], time: [826.2217], loss: [0.00367675]
# Epoch: [ 1], step: [980], time: [834.9191], loss: [0.01896071]
# Epoch: [ 1], step: [990], time: [843.1719], loss: [0.00816791]
# Epoch: [ 1], step: [1000], time: [851.3258], loss: [0.01779984]
# Epoch: [ 1], step: [1010], time: [859.5356], loss: [0.01197082]
# Epoch: [ 1], step: [1020], time: [867.7079], loss: [0.00881478]
# Epoch: [ 1], step: [1030], time: [875.8894], loss: [0.01426533]
# Epoch: [ 1], step: [1040], time: [884.0374], loss: [0.01656392]
# Epoch: [ 1], step: [1050], time: [892.2044], loss: [0.00747823]
# Epoch: [ 1], step: [1060], time: [900.3734], loss: [0.00410431]
# Epoch: [ 1], step: [1070], time: [908.6000], loss: [0.02794095]
# Epoch: [ 1], step: [1080], time: [916.7737], loss: [0.02242527]
# Epoch: [ 1], step: [1090], time: [925.0137], loss: [0.01099176]
# Epoch: [ 1], step: [1100], time: [933.8852], loss: [0.02779173]
# Epoch: [ 1], step: [1110], time: [942.9322], loss: [0.01130790]
# Epoch: [ 1], step: [1120], time: [951.2563], loss: [0.00373495]
# Epoch: [ 1], step: [1130], time: [959.4782], loss: [0.00489777]
# Epoch: [ 1], step: [1140], time: [967.6829], loss: [0.00749662]
# Epoch: [ 1], step: [1150], time: [975.8532], loss: [0.00622465]
# Epoch: [ 1], step: [1160], time: [984.0819], loss: [0.01165256]
# Epoch: [ 1], step: [1170], time: [992.3006], loss: [0.00231207]
# Epoch: [ 1], step: [1180], time: [1000.4364], loss: [0.00244627]
# Epoch: [ 1], step: [1190], time: [1009.1965], loss: [0.00689565]
# Epoch: [ 1], step: [1200], time: [1018.1032], loss: [0.00600495]
# Epoch: [ 1], step: [1210], time: [1026.3204], loss: [0.01118394]
# Epoch: [ 1], step: [1220], time: [1035.2657], loss: [0.01437739]
# Epoch: [ 1], step: [1230], time: [1043.9944], loss: [0.00513501]
# Epoch: [ 1], step: [1240], time: [1053.1975], loss: [0.00172219]
# Epoch: [ 1], step: [1250], time: [1061.9465], loss: [0.00646395]
# Epoch: [ 1], step: [1260], time: [1070.5177], loss: [0.00332098]
# Epoch: [ 1], step: [1270], time: [1078.9034], loss: [0.00101919]
# Epoch: [ 1], step: [1280], time: [1087.5032], loss: [0.00143763]
# Epoch: [ 1], step: [1290], time: [1096.1476], loss: [0.00849609]
# Epoch: [ 1], step: [1300], time: [1104.7827], loss: [0.00987660]
# Epoch: [ 1], step: [1310], time: [1113.0879], loss: [0.00277002]
# Epoch: [ 1], step: [1320], time: [1122.5423], loss: [0.00277408]
# Epoch: [ 1], step: [1330], time: [1130.8194], loss: [0.01152999]
# Epoch: [ 1], step: [1340], time: [1139.0318], loss: [0.00936655]
# Epoch: [ 1], step: [1350], time: [1147.2532], loss: [0.00283678]
# Epoch: [ 1], step: [1360], time: [1155.4775], loss: [0.00377791]
# Epoch: [ 1], step: [1370], time: [1163.7487], loss: [0.00833201]
# Epoch: [ 1], step: [1380], time: [1172.0113], loss: [0.00058746]
# Epoch: [ 1], step: [1390], time: [1180.9127], loss: [0.00345363]
# Epoch: [ 1], step: [1400], time: [1189.1149], loss: [0.00268157]
# Epoch: [ 1], step: [1410], time: [1197.3320], loss: [0.03011674]
# Epoch: [ 1], step: [1420], time: [1205.5209], loss: [0.00854993]
# Epoch: [ 1], step: [1430], time: [1214.3810], loss: [0.00704085]
# Epoch: [ 1], step: [1440], time: [1222.5890], loss: [0.00602347]
# Epoch: [ 1], step: [1450], time: [1230.8022], loss: [0.00991195]
# Epoch: [ 1], step: [1460], time: [1239.5916], loss: [0.00031804]
# Epoch: [ 1], step: [1470], time: [1247.7609], loss: [0.00510354]
# Epoch: [ 1], step: [1480], time: [1256.0077], loss: [0.00184768]
# Epoch: [ 1], step: [1490], time: [1264.4870], loss: [0.00602103]
# Epoch: [ 1], step: [1500], time: [1273.3353], loss: [0.00299728]
# Epoch: [ 1], step: [1510], time: [1281.7371], loss: [0.00370555]
# Epoch: [ 1], step: [1520], time: [1290.9387], loss: [0.00884792]
# Epoch: [ 1], step: [1530], time: [1299.9432], loss: [0.00663683]
# Epoch: [ 1], step: [1540], time: [1308.1502], loss: [0.01464423]
# Epoch: [ 1], step: [1550], time: [1316.4621], loss: [0.00669525]
# Epoch: [ 1], step: [1560], time: [1324.6853], loss: [0.01324462]
# Epoch: [ 1], step: [1570], time: [1332.8565], loss: [0.00803968]
# Epoch: [ 1], step: [1580], time: [1341.1149], loss: [0.00648444]
# Epoch: [ 1], step: [1590], time: [1349.3044], loss: [0.00263809]
# Epoch: [ 1], step: [1600], time: [1357.5212], loss: [0.01642949]
# Epoch: [ 1], step: [1610], time: [1365.7249], loss: [0.00551239]
# Epoch: [ 1], step: [1620], time: [1374.6797], loss: [0.02009998]
# Epoch: [ 1], step: [1630], time: [1382.8936], loss: [0.01558872]
# Epoch: [ 1], step: [1640], time: [1391.1168], loss: [0.01629807]
# Epoch: [ 1], step: [1650], time: [1399.3699], loss: [0.01031087]
# Epoch: [ 1], step: [1660], time: [1407.5567], loss: [0.01197879]
# Epoch: [ 1], step: [1670], time: [1415.8177], loss: [0.00693446]
# Epoch: [ 1], step: [1680], time: [1424.0236], loss: [0.00337455]
# Epoch: [ 1], step: [1690], time: [1432.1850], loss: [0.01839905]
# Epoch: [ 1], step: [1700], time: [1440.5046], loss: [0.01129920]
# Epoch: [ 1], step: [1710], time: [1449.5254], loss: [0.00734356]
# Epoch: [ 1], step: [1720], time: [1458.0802], loss: [0.00420805]
# Epoch: [ 1], step: [1730], time: [1466.4982], loss: [0.00617985]
# Epoch: [ 1], step: [1740], time: [1474.9588], loss: [0.00164397]
# Epoch: [ 1], step: [1750], time: [1483.4682], loss: [0.00113033]
# Epoch: [ 1], step: [1760], time: [1491.8290], loss: [0.00617768]
# Epoch: [ 1], step: [1770], time: [1499.9703], loss: [0.00852713]
# Epoch: [ 1], step: [1780], time: [1508.2148], loss: [0.01282629]
# Epoch: [ 1], step: [1790], time: [1516.4151], loss: [0.00391518]
# Epoch: [ 1], step: [1800], time: [1524.6206], loss: [0.01127797]
# Epoch: [ 1], step: [1810], time: [1533.5851], loss: [0.02179111]
# Epoch: [ 1], step: [1820], time: [1542.1465], loss: [0.01487382]
# Epoch: [ 1], step: [1830], time: [1550.3370], loss: [0.00275329]
# Epoch: [ 1], step: [1840], time: [1558.6115], loss: [0.01336004]
# Epoch: [ 1], step: [1850], time: [1566.8212], loss: [0.00406797]
# Epoch: [ 1], step: [1860], time: [1575.7275], loss: [0.00214257]
# Epoch: [ 1], step: [1870], time: [1584.0234], loss: [0.00255503]
# Epoch: [ 1], step: [1880], time: [1592.2583], loss: [0.00558699]
# Epoch: [ 1], step: [1890], time: [1601.6344], loss: [0.00314766]
# Epoch: [ 1], step: [1900], time: [1611.5180], loss: [0.00798545]
# Epoch: [ 1], step: [1910], time: [1619.7828], loss: [0.00921531]
# Epoch: [ 1], step: [1920], time: [1628.0147], loss: [0.01403837]
# Epoch: [ 1], step: [1930], time: [1636.1673], loss: [0.01195236]
# Epoch: [ 1], step: [1940], time: [1644.4162], loss: [0.00151747]
# Epoch: [ 1], step: [1950], time: [1653.5766], loss: [0.02434555]
# Epoch: [ 1], step: [1960], time: [1662.5328], loss: [0.01051818]
# Epoch: [ 1], step: [1970], time: [1672.6791], loss: [0.01607432]
# Epoch: [ 1], step: [1980], time: [1682.7301], loss: [0.00204302]
# Epoch: [ 1], step: [1990], time: [1692.2264], loss: [0.00864821]
# Epoch: [ 1], step: [2000], time: [1700.8218], loss: [0.01302108]
# Epoch: [ 1], step: [2010], time: [1708.9908], loss: [0.00958811]
# Epoch: [ 1], step: [2020], time: [1719.4770], loss: [0.02318693]
# Epoch: [ 1], step: [2030], time: [1728.1564], loss: [0.01071199]
# Epoch: [ 1], step: [2040], time: [1736.2806], loss: [0.00558156]
# Epoch: [ 1], step: [2050], time: [1744.3855], loss: [0.00576113]
# Epoch: [ 1], step: [2060], time: [1752.4404], loss: [0.01208592]
# Epoch: [ 1], step: [2070], time: [1760.5439], loss: [0.03282996]
# Epoch: [ 1], step: [2080], time: [1768.6505], loss: [0.00148228]
# Epoch: [ 1], step: [2090], time: [1776.7886], loss: [0.00202784]
# Epoch: [ 1], step: [2100], time: [1784.9085], loss: [0.00257602]
# Epoch: [ 1], step: [2110], time: [1793.2844], loss: [0.00030377]
# Epoch: [ 1], step: [2120], time: [1801.9915], loss: [0.00550965]
# Epoch: [ 1], step: [2130], time: [1810.0985], loss: [0.00088302]
# Epoch: [ 1], step: [2140], time: [1818.3045], loss: [0.03092758]
# Epoch: [ 1], step: [2150], time: [1826.3873], loss: [0.00995461]
# Epoch: [ 1], step: [2160], time: [1834.5269], loss: [0.01070292]
# Epoch: [ 1], step: [2170], time: [1842.6279], loss: [0.00537541]
# Epoch: [ 1], step: [2180], time: [1850.7180], loss: [0.01089970]
# Epoch: [ 1], step: [2190], time: [1858.8533], loss: [0.00374624]
# Epoch: [ 1], step: [2200], time: [1866.9360], loss: [0.00714448]
# Epoch: [ 1], step: [2210], time: [1875.0015], loss: [0.00249861]
# Epoch: [ 1], step: [2220], time: [1883.1241], loss: [0.01940603]
# Epoch: [ 1], step: [2230], time: [1891.1871], loss: [0.01095102]
# Epoch: [ 1], step: [2240], time: [1899.3397], loss: [0.00814124]
# Epoch: [ 1], step: [2250], time: [1907.3828], loss: [0.00376208]
# Epoch: [ 1], step: [2260], time: [1915.3743], loss: [0.00614763]
# Epoch: [ 1], step: [2270], time: [1923.4760], loss: [0.01627095]
# Epoch: [ 1], step: [2280], time: [1931.5829], loss: [0.01414170]
# Epoch: [ 1], step: [2290], time: [1939.7231], loss: [0.00902861]
# Epoch: [ 1], step: [2300], time: [1947.8857], loss: [0.00673169]
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN
# ['/Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0969.jpg', '/Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0955.jpg', '/Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1493.jpg']
# Saving  1 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1373.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 14 32
# Saving  2 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1414.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 23 22
# Saving  3 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0016.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 14 32
# Saving  4 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0239.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 13 32
# Saving  5 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1016.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  6 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1082.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  7 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1490.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 26 19
# Saving  8 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0543.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  9 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0843.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  10 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0705.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  11 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0574.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 23 23
# Saving  12 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1178.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  13 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0214.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  14 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0995.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  15 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0914.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 23 23
# Saving  16 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0367.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  17 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0517.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  18 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0879.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 23 23
# Saving  19 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0431.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  20 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0665.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 20 25
# Saving  21 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1206.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  22 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0396.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 11 35
# Saving  23 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0144.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  24 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0935.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  25 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0295.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  26 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0825.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  27 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0015.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  28 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0439.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  29 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0835.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  30 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0534.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  31 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1033.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 26 19
# Saving  32 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0679.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  33 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0801.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  34 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0569.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  35 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0936.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 23 23
# Saving  36 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1459.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  37 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0058.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 13 32
# Saving  38 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0124.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  39 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0905.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 23 23
# Saving  40 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0022.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 26 19
# Saving  41 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0099.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 20 25
# Saving  42 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0336.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  43 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1395.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 20 26
# Saving  44 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1494.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  45 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0347.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 27
# Saving  46 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0094.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  47 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0553.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  48 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1167.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  49 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0586.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  50 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0088.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 23 23
# Saving  51 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1277.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  52 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1133.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 26 19
# Saving  53 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1083.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 21 25
# Saving  54 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0718.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 27
# Saving  55 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1174.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 20 25
# Saving  56 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0711.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 23 23
# Saving  57 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0806.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  58 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1410.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  59 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0802.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  60 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0559.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  61 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0371.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  62 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0871.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 27
# Saving  63 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0961.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 20 25
# Saving  64 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0394.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 20 25
# Saving  65 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0647.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  66 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1131.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  67 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0664.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 27
# Saving  68 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1394.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  69 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0854.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  70 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0006.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 20 25
# Saving  71 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0064.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  72 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1297.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# Saving  73 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0159.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  74 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1046.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  75 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1260.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  76 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0055.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  77 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1048.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  78 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1314.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 21 24
# Saving  79 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1255.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 27
# Saving  80 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1454.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 29
# Saving  81 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0883.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  82 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0075.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 27
# Saving  83 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0933.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  84 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1066.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 18 28
# Saving  85 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1271.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  86 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1401.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 20 25
# Saving  87 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0171.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 15 30
# Saving  88 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0112.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 16 29
# Saving  89 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1301.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 17 28
# Saving  90 / 300 :  /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0381.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/checkpoint1/srcnn_21/SRCNN.model-2300
# 21 21
# 19 26
# ...
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0256.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0709.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0887.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1417.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1172.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1371.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1280.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1359.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0560.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0906.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1248.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0090.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0473.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1239.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0072.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1013.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1447.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0442.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1399.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0867.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1253.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0126.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0716.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0085.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0765.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0052.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0604.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1358.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0149.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1172.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0410.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0278.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0349.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1101.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0962.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0586.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0742.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0747.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1214.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1459.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1158.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0035.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1101.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0960.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1367.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1277.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0660.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0431.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0539.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1061.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1138.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0394.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0867.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0381.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0740.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1060.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0385.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0342.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1106.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1048.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1124.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0801.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0315.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0632.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0184.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0961.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0233.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0949.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0747.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0008.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0080.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0752.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1421.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1458.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0405.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0546.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0090.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0036.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0497.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0022.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1161.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1314.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1437.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0778.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0459.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1248.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0326.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1260.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0147.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0618.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1027.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0383.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1060.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0396.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1270.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0816.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0921.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0802.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0816.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0962.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0844.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1301.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1223.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1473.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0661.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0553.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0329.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0543.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1108.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0594.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0766.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1463.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0857.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0755.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0290.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1271.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0984.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0147.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1483.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1259.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1109.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0153.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0332.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0806.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0910.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0184.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1341.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0190.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1067.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1067.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0904.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0345.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1085.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0422.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1417.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1072.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0048.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1066.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1013.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0634.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0190.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1270.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0422.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0026.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_1259.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0740.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0541.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0032.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0789.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_0230.png
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/train_set/LR/img_0906.jpg
# /Users/wanyiellenzheng/Documents/GitHub/Fall2018-Proj3-Sec2-grp7/TensorFlow-SRCNN/result/img_1106.png
# 27.9092649976147

# %%
# ################ psnr error for final model
# import numpy
# import math
# import cv2
# import os, glob
# # def psnr(img1, img2):
# #     mse = numpy.mean( (img1 - img2) ** 2 )
# #     if mse == 0:
# #         return 100
# #     PIXEL_MAX = 255.0
# #     return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# path = os.getcwd()
# for x in range(len(path_result)):    

#     test_imgs = glob.glob(test_result[x])
#     res_imgs = glob.glob(os.path.join(os.getcwd(), 'result', '*.png'))

#     psnr_total = []

#     for i in range(len(test_imgs)): 

#         img1 = cv2.imread(test_imgs[i], cv2.IMREAD_COLOR)
#         img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2YCrCb)[6: -6, 6: -6, 0] 
#         img2 = cv2.imread(res_imgs[i], cv2.IMREAD_COLOR)
#         img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2YCrCb)[6: -6, 6: -6, 0] 
#         img1 = cv2.resize(img1,(img2.shape[1],img2.shape[0]))
#         psnr_total.append(psnr(img1,img2))
    
# print(np.mean(psnr_total))
