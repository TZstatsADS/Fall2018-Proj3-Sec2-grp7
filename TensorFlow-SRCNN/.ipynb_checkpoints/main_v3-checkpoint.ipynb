# %%
import cv2
import numpy as np
import tensorflow as tf
import os 
import glob
import h5py
import time

# Get the Image
def imread(path):
    img = cv2.imread(path)
    return img

def imsave(image, path, config):
    #checkimage(image)
    # Check the check dir, if not, create one
    if not os.path.isdir(os.path.join(os.getcwd(),config.result_dir)):
        os.makedirs(os.path.join(os.getcwd(),config.result_dir))

    # NOTE: because normial, we need mutlify 255 back    
    cv2.imwrite(os.path.join(os.getcwd(),path),image * 255.)

def checkimage(image):
    cv2.imshow('test',image)
    cv2.waitKey(0)

def modcrop(img, scale =3):
    """
        To scale down and up the original image, first thing to do is to have no remainder while scaling operation.
    """
    # Check the image is grayscale
    if len(img.shape) ==3:
        h, w, _ = img.shape
        h = (h // scale) * scale
        w = (w // scale) * scale
        img = img[0:h, 0:w, :]
    else:
        h, w = img.shape
        h = (h // scale) * scale
        w = (w // scale) * scale
        img = img[0:h, 0:w]
    return img

def checkpoint_dir(config):
    if config.is_train:
        return os.path.join('./{}'.format(config.checkpoint_dir), 'train.h5')
    else:
        return os.path.join('./{}'.format(config.checkpoint_dir), 'test.h5')

def preprocess(path, scale = 3):
    img = imread(path)
    #img=cv2.resize(img,None,fx = 2 ,fy = 2, interpolation = cv2.INTER_CUBIC)

    label_ = modcrop(img, scale)
    
    bicbuic_img = cv2.resize(label_, None, fx = 1.0/scale, fy = 1.0/scale, interpolation = cv2.INTER_CUBIC)# Resize by scaling factor
    input_ = cv2.resize(bicbuic_img, None, fx = scale, fy = scale, interpolation = cv2.INTER_CUBIC)# Resize by scaling factor
    return input_, label_

def prepare_data(dataset='Train',Input_img=''):
    """
        Args:
            dataset: choose train dataset or test dataset
            For train dataset, output data would be ['.../t1.bmp', '.../t2.bmp',..., 't99.bmp']
    """
    if dataset == 'Train':
        data_dir = os.path.join(os.getcwd(), dataset) # Join the Train dir to current directory
        data = glob.glob(os.path.join(data_dir, '*.*')) # make set of all dataset file path
    else:
        if Input_img !='':
            data = [os.path.join(os.getcwd(),Input_img)]
        else:
            data_dir = os.path.join(os.path.join(os.getcwd(), dataset), 'Set5')
            data = glob.glob(os.path.join(data_dir, '*.*')) # make set of all dataset file path
    print(data)
    return data

def load_data(is_train, test_img):
    """
        Args:
            is_train: decides if we choose train dataset or test dataset
            For train dataset, output data would be ['.../t1.bmp', '.../t2.bmp',..., 't99.bmp']
    """
    if is_train:
        data_dir = os.path.join(os.getcwd(), 'Train') # Join the Train dir to current directory
        data = glob.glob(os.path.join(data_dir, '*.*')) # make set of all dataset file path
    else:
        if test_img != '':
            return [os.path.join(os.getcwd(), test_img)]
        data_dir = os.path.join(os.path.join(os.getcwd(), 'Test'), 'Set5')
        data = glob.glob(os.path.join(data_dir, '*.*')) # make set of all dataset file path
    return data

def make_sub_data(data, padding, config):
    """
        Make the sub_data set
        Args:
            data : the set of all file path 
            padding : the image padding of input to label
            config : the all flags
    """
    sub_input_sequence = []
    sub_label_sequence = []
    for i in range(len(data)):
        if config.is_train:
            input_, label_, = preprocess(data[i], config.scale) # do bicubic
        else: # Test just one picture
            input_, label_, = preprocess(data[i], config.scale) # do bicubic
        
        if len(input_.shape) == 3: # is color
            h, w, c = input_.shape
        else:
            h, w = input_.shape # is grayscale
        #checkimage(input_)
        nx, ny = 0, 0
        for x in range(0, h - config.image_size + 1, config.stride):
            nx += 1; ny = 0
            for y in range(0, w - config.image_size + 1, config.stride):
                ny += 1

                sub_input = input_[x: x + config.image_size, y: y + config.image_size] # 33 * 33
                sub_label = label_[x + padding: x + padding + config.label_size, y + padding: y + padding + config.label_size] # 21 * 21

                # Reshape the subinput and sublabel
                sub_input = sub_input.reshape([config.image_size, config.image_size, config.c_dim])
                sub_label = sub_label.reshape([config.label_size, config.label_size, config.c_dim])
                # Normialize
                sub_input =  sub_input / 255.0
                sub_label =  sub_label / 255.0
                
                #cv2.imshow('im1',sub_input)
                #cv2.imshow('im2',sub_label)
                #cv2.waitKey(0)

                # Add to sequence
                sub_input_sequence.append(sub_input)
                sub_label_sequence.append(sub_label)
        
    # NOTE: The nx, ny can be ignore in train
    return sub_input_sequence, sub_label_sequence, nx, ny


def read_data(path):
    """
        Read h5 format data file

        Args:
            path: file path of desired file
            data: '.h5' file format that contains  input values
            label: '.h5' file format that contains label values 
    """
    with h5py.File(path, 'r') as hf:
        input_ = np.array(hf.get('input'))
        label_ = np.array(hf.get('label'))
        return input_, label_

def make_data_hf(input_, label_, config):
    """
        Make input data as h5 file format
        Depending on 'is_train' (flag value), savepath would be change.
    """
    # Check the check dir, if not, create one
    if not os.path.isdir(os.path.join(os.getcwd(),config.checkpoint_dir)):
        os.makedirs(os.path.join(os.getcwd(),config.checkpoint_dir))

    if config.is_train:
        savepath = os.path.join(os.getcwd(), config.checkpoint_dir + '/train.h5')
    else:
        savepath = os.path.join(os.getcwd(), config.checkpoint_dir + '/test.h5')

    with h5py.File(savepath, 'w') as hf:
        hf.create_dataset('input', data=input_)
        hf.create_dataset('label', data=label_)

def merge(images, size, c_dim):
    """
        images is the sub image set, merge it
    """
    h, w = images.shape[1], images.shape[2]
    
    img = np.zeros((h*size[0], w*size[1], c_dim))
    for idx, image in enumerate(images):
        i = idx % size[1]
        j = idx // size[1]
        img[j * h : j * h + h, i * w : i * w + w, :] = image
        #cv2.imshow('srimg',img)
        #cv2.waitKey(0)
        
    return img

def input_setup(config):
    """
        Read image files and make their sub-images and saved them as a h5 file format
    """

    # Load data path, if is_train False, get test data
    data = load_data(config.is_train, config.test_img)

    padding = abs(config.image_size - config.label_size) // 2

    # Make sub_input and sub_label, if is_train false more return nx, ny
    sub_input_sequence, sub_label_sequence, nx, ny = make_sub_data(data, padding, config)


    # Make list to numpy array. With this transform
    arrinput = np.asarray(sub_input_sequence) # [?, 33, 33, 3]
    arrlabel = np.asarray(sub_label_sequence) # [?, 21, 21, 3]

    make_data_hf(arrinput, arrlabel, config)

    return nx, ny


#######################################
#                                     #
#          FOR TRAINING ONLY          #
#                                     #
#######################################

def load_data1(is_train):
    if is_train:
    # Divide files into train set and test set
        files_LR = glob.glob(os.path.join(os.getcwd(), 'train_set', 'LR', '*.jpg'))
        test_files_LR = random.sample(files_LR, len(files_LR)//5)
        train_files_LR = [_ for _ in files_LR if _ not in test_files_LR]
        data1=train_files_LR

        files_HR = glob.glob(os.path.join(os.getcwd(), 'train_set', 'HR', '*.jpg'))
        test_files_HR = random.sample(files_HR, len(files_HR)//5)
        train_files_HR = [_ for _ in files_HR if _ not in test_files_HR]
        data2=train_files_HR
    return data1,data2


def make_sub_data1(data1,data2, padding, config):
    """
        Make the sub_data set
        Args:
            data : the set of all file path 
            padding : the image padding of input to label
            config : the all flags
    """
    sub_input_sequence = []
    sub_label_sequence = []
    for i in range(len(data1)):
        if config.is_train:
            input_=data1[i]
            label_=data2[i]
            
            input_=cv2.imread(input_)
            label_=cv2.imread(label_)

        if len(input_.shape) == 3: # is color
            h, w, c = input_.shape
        else:
            h, w = input_.shape # is grayscale
 
        #nx, ny = 0, 0
        for x in range(0, h - config.image_size + 1, config.stride):
#             nx += 1; ny = 0
            for y in range(0, w - config.image_size + 1, config.stride):
#                 ny += 1

                sub_input = input_[x: x + config.image_size, y: y + config.image_size] # 33 * 33
                sub_label = label_[x + padding: x + padding + config.label_size, y + padding: y + padding + config.label_size] # 21 * 21


                # Reshape the subinput and sublabel
                sub_input = sub_input.reshape([config.image_size, config.image_size, config.c_dim])
                sub_label = sub_label.reshape([config.label_size, config.label_size, config.c_dim])
                # Normialize
                sub_input =  sub_input / 255.0
                sub_label =  sub_label / 255.0
                
                #cv2.imshow("im1",sub_input)
                #cv2.imshow("im2",sub_label)
                #cv2.waitKey(0)

                # Add to sequence
                sub_input_sequence.append(sub_input)
                sub_label_sequence.append(sub_label)

        
    # NOTE: The nx, ny can be ignore in train
    return sub_input_sequence, sub_label_sequence#, nx, ny

def make_data_hf1(input_, label_, config):
    """
        Make input data as h5 file format
        Depending on "is_train" (flag value), savepath would be change.
    """
    # Check the check dir, if not, create one
    if not os.path.isdir(os.path.join(os.getcwd(),config.checkpoint_dir)):
        os.makedirs(os.path.join(os.getcwd(),config.checkpoint_dir))

    if config.is_train:
        savepath = os.path.join(os.getcwd(), config.checkpoint_dir + '/train.h5')

    with h5py.File(savepath, 'w') as hf:
        hf.create_dataset('input', data=input_)
        hf.create_dataset('label', data=label_)

def input_setup1(config):
    """
        Read image files and make their sub-images and saved them as a h5 file format
    """
    print('.')
    # Load data path, if is_train False, get test data
    data1, data2 = load_data1(config.is_train)
    print('..')
    padding = abs(config.image_size - config.label_size) // 2
    print('...')
    # Make sub_input and sub_label, if is_train false more return nx, ny
    sub_input_sequence, sub_label_sequence = make_sub_data1(data1,data2, padding, config)

    print('....')
    # Make list to numpy array. With this transform
    arrinput = np.asarray(sub_input_sequence) # [?, 33, 33, 3]
    arrlabel = np.asarray(sub_label_sequence) # [?, 21, 21, 3]
    print('.....')
    make_data_hf1(arrinput, arrlabel, config)
    
#     return nx, ny


def checkpoint_dir1(config):
    if config.is_train:
        return os.path.join('./{}'.format(config.checkpoint_dir), "train.h5")
    #else:
        #return os.path.join('./{}'.format(config.checkpoint_dir), "test.h5")


def read_data1(path):
    """
        Read h5 format data file

        Args:
            path: file path of desired file
            data: '.h5' file format that contains  input values
            label: '.h5' file format that contains label values 
    """
    with h5py.File(path, 'r') as hf:
        input_ = np.array(hf.get('input'))
        label_ = np.array(hf.get('label'))
        return input_, label_

# %%
class SRCNN(object):

    def __init__(self, sess, image_size, label_size, c_dim):
        self.sess = sess
        self.image_size = image_size
        self.label_size = label_size
        self.c_dim = c_dim
        self.build_model()

    def build_model(self):
        self.images = tf.placeholder(tf.float32, [None, self.image_size, self.image_size, self.c_dim], name='images')
        self.labels = tf.placeholder(tf.float32, [None, self.label_size, self.label_size, self.c_dim], name='labels')
        
        self.weights = {
            'w1': tf.Variable(tf.random_normal([9, 9, self.c_dim, 64], stddev=1e-3), name='w1'),
            'w2': tf.Variable(tf.random_normal([1, 1, 64, 32], stddev=1e-3), name='w2'),
            'w3': tf.Variable(tf.random_normal([5, 5, 32, self.c_dim], stddev=1e-3), name='w3')
        }
        self.biases = {
            'b1': tf.Variable(tf.zeros([64], name='b1')),
            'b2': tf.Variable(tf.zeros([32], name='b2')),
            'b3': tf.Variable(tf.zeros([self.c_dim], name='b3'))
        }
        self.pred = self.model()
        self.loss = tf.reduce_mean(tf.square(self.labels - self.pred))
        self.saver = tf.train.Saver() # To save checkpoint

    def model(self):
        conv1 = tf.nn.relu(tf.nn.conv2d(self.images, self.weights['w1'], strides=[1,1,1,1], padding='VALID') + self.biases['b1'])
        conv2 = tf.nn.relu(tf.nn.conv2d(conv1, self.weights['w2'], strides=[1,1,1,1], padding='VALID') + self.biases['b2'])
        conv3 = tf.nn.conv2d(conv2, self.weights['w3'], strides=[1,1,1,1], padding='VALID') + self.biases['b3'] # This layer don't need ReLU
        return conv3

#     def train(self, config):
#         # NOTE : if train, the nx, ny are ingnored
#         nx, ny = input_setup(config)

#         data_dir = checkpoint_dir(config)
        
#         input_, label_ = read_data(data_dir)
#         # Stochastic gradient descent with the standard backpropagation
#         #self.train_op = tf.train.GradientDescentOptimizer(config.learning_rate).minimize(self.loss)
#         self.train_op = tf.train.AdamOptimizer(learning_rate=config.learning_rate).minimize(self.loss)
#         tf.global_variables_initializer().run()
        
#         counter = 0
#         time_ = time.time()

#         self.load(config.checkpoint_dir)
        
#         print('Now Start Training...')
#         for ep in range(config.epoch):
#             # Run by batch images
#             batch_idxs = len(input_) // config.batch_size
#             for idx in range(0, batch_idxs):
#                 batch_images = input_[idx * config.batch_size : (idx + 1) * config.batch_size]
#                 batch_labels = label_[idx * config.batch_size : (idx + 1) * config.batch_size]
#                 counter += 1
#                 _, err = self.sess.run([self.train_op, self.loss], feed_dict={self.images: batch_images, self.labels: batch_labels})

#                 if counter % 10 == 0:
#                     print('Epoch: [%2d], step: [%2d], time: [%4.4f], loss: [%.8f]' % ((ep+1), counter, time.time()-time_, err))
#                     #print(label_[1] - self.pred.eval({self.images: input_})[1],'loss:]',err)
#                 if counter % 500 == 0:
#                     self.save(config.checkpoint_dir, counter)
    def train(self, config):
        # NOTE : if train, the nx, ny are ingnored
        input_setup1(config)
        print(1)
        data_dir = checkpoint_dir1(config)
        print(2)
        input_, label_ = read_data1(data_dir)
        print(3)
        self.train_op = tf.train.AdamOptimizer(learning_rate=config.learning_rate).minimize(self.loss)
        tf.global_variables_initializer().run()
        print(4)
        counter = 0
        time_ = time.time()

        # Train
        if config.is_train:
            print("Now Start Training...")
            for ep in range(config.epoch):
                # Run by batch images
                batch_idxs = len(input_) // config.batch_size
                print('len(input_) =', batch_idxs)
                for idx in range(0, batch_idxs):
#                     print('ep =', ep, 'batch # ', idx)
                    batch_images = input_[idx * config.batch_size : (idx + 1) * config.batch_size]
                    batch_labels = label_[idx * config.batch_size : (idx + 1) * config.batch_size]
                    counter += 1
                    _, err = self.sess.run([self.train_op, self.loss], feed_dict={self.images: batch_images, self.labels: batch_labels})

                    if counter % 10 == 0:
                        print("Epoch: [%2d], step: [%2d], time: [%4.4f], loss: [%.8f]" % ((ep+1), counter, time.time()-time_, err))
                        #print(label_[1] - self.pred.eval({self.images: input_})[1],'loss:]',err)
                    if counter % 10 == 0:
                        self.save(config.checkpoint_dir, counter)
                    
    def test(self, config):
        print('Testing...')
        nx, ny = input_setup(config)
        data_dir = checkpoint_dir(config)
        input_, label_ = read_data(data_dir)

        self.load(config.checkpoint_dir)
        
        result = self.pred.eval({self.images: input_})
#             print(label_[1] - result[1])
        image = merge(result, [nx, ny], self.c_dim)
        #image_LR = merge(input_, [nx, ny], self.c_dim)
        #checkimage(image_LR)
#         print('Now Saving Image...')
        fname = os.path.basename(config.test_img)
        base, ext = fname.split('.')
        imsave(image, os.path.join(config.result_dir, base+'.png'), config)

    def load(self, checkpoint_dir):
        """
            To load the checkpoint use to test or pretrain
        """
        model_dir = '%s_%s' % ('srcnn', self.label_size)# give the model name by label_size
        checkpoint_dir = os.path.join(checkpoint_dir, model_dir)
        ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
        
        # Check the checkpoint is exist 
        if ckpt and ckpt.model_checkpoint_path:
            ckpt_path = str(ckpt.model_checkpoint_path) # convert the unicode to string
            self.saver.restore(self.sess, os.path.join(os.getcwd(), ckpt_path))
#             print('Success! %s'% ckpt_path)
        else:
            print('Loading failed.')
    def save(self, checkpoint_dir, step):
        """
            To save the checkpoint use to test or pretrain
        """
        model_name = 'SRCNN.model'
        model_dir = '%s_%s' % ('srcnn', self.label_size)
        checkpoint_dir = os.path.join(checkpoint_dir, model_dir)

        if not os.path.exists(checkpoint_dir):
             os.makedirs(checkpoint_dir)

        self.saver.save(self.sess,
                        os.path.join(checkpoint_dir, model_name),
                        global_step=step)

# %%
import tensorflow as tf
import numpy as np
import pprint
import os
import glob
import random

random.seed(83)

class this_config():
    def __init__(self, is_train=True):
        self.epoch = 1
        self.image_size = 33
        self.label_size = 21
        self.c_dim = 3
        self.is_train = is_train
        self.scale = 3
        self.stride = 21
        self.checkpoint_dir = 'checkpoint'
        self.learning_rate = 1e-4
        self.batch_size = 128
        self.result_dir = 'result'
        self.test_img = '' # Do not change this.
        
FLAGS = this_config()
with tf.Session() as sess:
    # Divide files into train set and test set
    files = glob.glob(os.path.join(os.getcwd(), 'train_set', 'LR', '*.jpg'))
    test_files = random.sample(files, len(files)//5)
    train_files = [_ for _ in files if _ not in test_files]
    
    # Create an instance of SRCNN model
    srcnn = SRCNN(sess,
                  image_size = FLAGS.image_size,
                  label_size = FLAGS.label_size,
                  c_dim = FLAGS.c_dim)
    
    # Training
    srcnn.train(FLAGS)

    # Testing
    FLAGS.is_train = False
    count = 1
    for f in test_files:
        FLAGS.test_img = f
        print('Saving ', count, '/', len(test_files), ': ', FLAGS.test_img, '\n')
        count += 1
        srcnn.test(FLAGS)
# Out:
# Saving  1 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1373.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  2 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1414.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  3 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0016.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  4 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0239.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  5 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1016.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  6 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1082.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  7 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1490.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  8 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0543.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  9 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0843.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  10 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0705.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  11 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0574.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  12 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1178.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  13 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0214.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  14 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0995.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  15 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0914.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  16 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0367.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  17 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0517.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  18 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0879.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  19 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0431.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  20 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0665.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  21 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1206.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  22 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0396.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  23 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0144.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  24 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0935.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  25 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0295.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  26 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0825.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  27 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0015.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  28 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0439.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  29 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0835.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  30 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0534.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  31 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1033.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  32 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0679.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  33 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0801.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  34 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0569.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  35 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0936.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  36 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1459.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  37 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0058.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  38 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0124.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  39 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0905.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  40 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0022.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  41 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0099.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  42 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0336.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  43 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1395.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  44 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1494.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  45 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0347.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  46 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0094.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  47 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0553.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  48 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1167.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  49 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0586.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  50 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0088.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  51 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1277.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  52 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1133.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  53 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1083.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  54 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0718.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  55 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1174.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  56 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0711.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  57 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0806.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  58 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1410.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  59 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0802.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  60 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0559.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  61 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0371.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  62 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0871.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  63 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0961.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  64 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0394.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  65 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0647.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  66 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1131.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  67 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0664.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  68 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1394.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  69 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0854.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  70 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0006.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  71 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0064.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  72 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1297.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  73 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0159.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  74 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1046.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  75 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1260.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  76 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0055.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  77 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1048.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  78 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1314.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  79 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1255.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  80 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1454.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  81 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0883.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  82 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0075.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  83 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0933.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  84 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1066.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  85 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1271.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  86 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1401.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  87 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0171.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  88 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0112.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  89 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1301.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  90 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0381.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  91 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1236.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  92 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0035.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  93 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0342.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  94 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1463.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  95 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0104.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  96 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0778.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  97 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0612.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  98 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1371.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  99 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0861.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  100 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0068.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  101 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1473.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  102 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0321.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  103 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1072.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  104 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0576.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  105 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1309.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  106 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0083.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  107 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0628.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  108 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0752.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  109 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0623.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  110 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0291.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  111 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0164.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  112 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1094.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  113 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0131.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  114 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1357.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  115 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0118.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  116 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0187.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  117 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1042.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  118 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1239.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  119 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0490.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  120 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0230.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  121 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0771.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  122 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0652.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  123 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0618.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  124 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0987.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  125 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0008.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  126 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0554.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  127 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0242.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  128 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0687.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  129 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0188.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  130 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0688.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  131 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1002.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  132 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1420.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  133 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0863.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  134 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0831.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  135 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0923.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  136 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0947.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  137 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0217.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  138 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1293.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  139 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0279.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  140 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0755.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  141 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0390.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  142 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1359.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  143 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0838.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  144 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1335.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  145 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0698.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  146 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0942.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  147 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0521.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  148 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0685.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  149 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1279.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  150 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0413.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  151 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1061.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  152 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1356.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  153 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0383.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  154 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0492.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  155 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1149.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  156 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0594.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  157 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0012.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  158 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1282.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  159 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1186.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  160 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0960.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  161 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1179.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  162 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0468.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  163 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0472.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  164 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0709.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  165 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0114.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  166 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0810.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  167 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0450.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  168 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0653.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  169 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0278.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  170 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1195.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  171 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0402.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  172 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1224.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  173 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0909.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  174 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1147.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  175 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0781.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  176 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0524.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  177 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0949.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  178 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0555.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  179 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0056.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  180 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0809.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  181 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1247.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  182 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0126.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  183 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1112.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  184 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0634.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  185 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0095.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  186 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0632.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  187 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0151.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  188 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0327.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  189 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0691.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  190 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0694.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  191 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1192.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  192 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0775.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  193 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1423.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  194 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0546.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  195 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0005.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  196 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0461.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  197 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1358.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  198 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0738.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  199 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0882.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  200 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1331.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  201 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1092.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  202 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1400.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  203 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0311.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  204 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1183.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  205 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1405.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  206 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0121.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  207 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0598.jpg
#
# Testing...
# ...
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  233 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1447.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  234 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1399.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  235 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1253.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  236 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0716.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  237 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0765.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  238 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0604.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  239 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0149.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  240 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0410.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  241 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0349.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  242 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0962.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  243 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0742.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  244 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1214.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  245 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1158.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  246 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1101.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  247 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1367.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  248 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0660.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  249 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0539.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  250 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1138.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  251 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0867.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  252 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0740.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  253 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0385.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  254 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1106.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  255 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1124.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  256 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0315.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  257 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0184.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  258 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0233.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  259 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0747.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  260 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0080.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  261 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1421.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  262 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0405.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  263 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0090.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  264 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0497.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  265 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1161.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  266 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1437.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  267 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0459.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  268 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0326.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  269 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0147.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  270 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1027.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  271 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1060.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  272 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1270.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  273 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0921.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  274 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0816.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  275 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0844.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  276 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1223.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  277 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0661.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  278 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0329.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  279 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1108.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  280 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0766.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  281 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0857.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  282 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0290.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  283 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0984.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  284 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1483.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  285 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1109.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  286 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0332.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  287 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0910.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  288 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1341.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  289 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1067.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  290 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0904.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  291 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1085.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  292 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1417.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  293 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0048.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  294 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1013.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  295 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0190.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  296 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0422.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  297 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_1259.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  298 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0541.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  299 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0789.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090
# Saving  300 / 300 :  /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/train_set/LR/img_0906.jpg
#
# Testing...
# INFO:tensorflow:Restoring parameters from /Users/yaoqi/Google Drive/TensorFlow-SRCNN-new/checkpoint/srcnn_21/SRCNN.model-2090

# %%
### path, files playground ###

# import os
# import glob
# import random
# random.seed(83)
# files = glob.glob(os.path.join(os.getcwd(), 'train_set', 'LR', '*.*'))
# test_files = random.sample(files, len(files)//5)
# train_files = [_ for _ in files if _ not in test_files]
# print(len(train_files), train_files[:])

# files2 = glob.glob(os.path.join(os.getcwd(), 'train_set', 'HR', '*.*'))
# test_files2 = random.sample(files2, len(files2)//5)
# train_files2 = [_ for _ in files2 if _ not in test_files2]
# print(len(train_files2), train_files2[0:3])


# filename = os.path.basename(test_files[0])
# base, ext = filename.split('.')
# # print(filename, base, ext)
